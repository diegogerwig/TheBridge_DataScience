# %% [markdown]
# # Obtén y conoce tus datos

# %% [markdown]
# ### 1. Importa las librerías necesarias

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 2. Importa el dataset de este [enlace](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user) y guárdalo en una variable llamada users. Usa pd.read_csv()

# %%
file = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user'
data = pd.read_csv(file, sep='|', index_col='user_id')
data
# Out:
#          age gender     occupation zip_code
# user_id
# 1         24      M     technician    85711
# 2         53      F          other    94043
# 3         23      M         writer    32067
# 4         24      M     technician    43537
# 5         33      F          other    15213
# ...      ...    ...            ...      ...
# 939       26      F        student    33319
# 940       32      M  administrator    02215
# 941       20      M        student    97229
# 942       48      F      librarian    78209
# 943       22      M        student    77841
#
# [943 rows x 4 columns]

# %% [markdown]
# ### 3. Muestra las 25 primeros registros

# %%
data[0:25]
# Out:
#          age gender     occupation zip_code
# user_id
# 1         24      M     technician    85711
# 2         53      F          other    94043
# 3         23      M         writer    32067
# 4         24      M     technician    43537
# 5         33      F          other    15213
# 6         42      M      executive    98101
# 7         57      M  administrator    91344
# 8         36      M  administrator    05201
# 9         29      M        student    01002
# 10        53      M         lawyer    90703
# 11        39      F          other    30329
# 12        28      F          other    06405
# 13        47      M       educator    29206
# 14        45      M      scientist    55106
# 15        49      F       educator    97301
# 16        21      M  entertainment    10309
# 17        30      M     programmer    06355
# 18        35      F          other    37212
# 19        40      M      librarian    02138
# 20        42      F      homemaker    95660
# 21        26      M         writer    30068
# 22        25      M         writer    40206
# 23        30      F         artist    48197
# 24        21      F         artist    94533
# 25        39      M       engineer    55107

# %% [markdown]
# ### 4. Muestra las 25 primeros registros de otra forma

# %%
data.head(25)
# Out:
#          age gender     occupation zip_code
# user_id
# 1         24      M     technician    85711
# 2         53      F          other    94043
# 3         23      M         writer    32067
# 4         24      M     technician    43537
# 5         33      F          other    15213
# 6         42      M      executive    98101
# 7         57      M  administrator    91344
# 8         36      M  administrator    05201
# 9         29      M        student    01002
# 10        53      M         lawyer    90703
# 11        39      F          other    30329
# 12        28      F          other    06405
# 13        47      M       educator    29206
# 14        45      M      scientist    55106
# 15        49      F       educator    97301
# 16        21      M  entertainment    10309
# 17        30      M     programmer    06355
# 18        35      F          other    37212
# 19        40      M      librarian    02138
# 20        42      F      homemaker    95660
# 21        26      M         writer    30068
# 22        25      M         writer    40206
# 23        30      F         artist    48197
# 24        21      F         artist    94533
# 25        39      M       engineer    55107

# %% [markdown]
# ### 5. Muestra los últimos 25 registros

# %%
data[-25:]
# Out:
#          age gender     occupation zip_code
# user_id
# 919       25      M          other    14216
# 920       30      F         artist    90008
# 921       20      F        student    98801
# 922       29      F  administrator    21114
# 923       21      M        student    E2E3R
# 924       29      M          other    11753
# 925       18      F       salesman    49036
# 926       49      M  entertainment    01701
# 927       23      M     programmer    55428
# 928       21      M        student    55408
# 929       44      M      scientist    53711
# 930       28      F      scientist    07310
# 931       60      M       educator    33556
# 932       58      M       educator    06437
# 933       28      M        student    48105
# 934       61      M       engineer    22902
# 935       42      M         doctor    66221
# 936       24      M          other    32789
# 937       48      M       educator    98072
# 938       38      F     technician    55038
# 939       26      F        student    33319
# 940       32      M  administrator    02215
# 941       20      M        student    97229
# 942       48      F      librarian    78209
# 943       22      M        student    77841

# %%
data.tail(25)
# Out:
#          age gender     occupation zip_code
# user_id
# 919       25      M          other    14216
# 920       30      F         artist    90008
# 921       20      F        student    98801
# 922       29      F  administrator    21114
# 923       21      M        student    E2E3R
# 924       29      M          other    11753
# 925       18      F       salesman    49036
# 926       49      M  entertainment    01701
# 927       23      M     programmer    55428
# 928       21      M        student    55408
# 929       44      M      scientist    53711
# 930       28      F      scientist    07310
# 931       60      M       educator    33556
# 932       58      M       educator    06437
# 933       28      M        student    48105
# 934       61      M       engineer    22902
# 935       42      M         doctor    66221
# 936       24      M          other    32789
# 937       48      M       educator    98072
# 938       38      F     technician    55038
# 939       26      F        student    33319
# 940       32      M  administrator    02215
# 941       20      M        student    97229
# 942       48      F      librarian    78209
# 943       22      M        student    77841

# %% [markdown]
# ### 6. Cuántos registros hay en total en este dataset?
# Resuélvelo de al menos dos formas diferentes

# %%
len(data)
# Out:
# 943

# %%
data.shape
# Out:
# (943, 4)

# %%
data.shape[0]
# Out:
# 943

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 943 entries, 1 to 943
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   age         943 non-null    int64
#  1   gender      943 non-null    object
#  2   occupation  943 non-null    object
#  3   zip_code    943 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 36.8+ KB

# %% [markdown]
# ### 7. Cuántas columnas hay en total en este dataset?
# Resuélvelo de al menos dos formas diferentes

# %%
data.shape[1]
# Out:
# 4

# %%
len(data.columns)
# Out:
# 4

# %% [markdown]
# ### 8. Haz un print de cada uno de los nombres de las columnas

# %%
print(*data.columns.values)
# Out:
# age gender occupation zip_code

# %%
data.head(0)
# Out:
# Empty DataFrame
# Columns: [age, gender, occupation, zip_code]
# Index: []

# %% [markdown]
# ### 9. Accede al índice, a los nombres de las columnas y a los valores por separado

# %%
data.index[0]
# Out:
# 1

# %% [markdown]
# ### 10. Cuál es el tipo de cada columna del dataset?
# Hazlo de dos formas diferentes

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 943 entries, 1 to 943
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   age         943 non-null    int64
#  1   gender      943 non-null    object
#  2   occupation  943 non-null    object
#  3   zip_code    943 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 36.8+ KB

# %%
data.dtypes
# Out:
# age            int64
# gender        object
# occupation    object
# zip_code      object
# dtype: object

# %% [markdown]
# ### 11. Haz un print solo de la columna de occupation
# Hazlo de dos formas diferentes

# %%
data['occupation']
# Out:
# user_id
# 1         technician
# 2              other
# 3             writer
# 4         technician
# 5              other
#            ...
# 939          student
# 940    administrator
# 941          student
# 942        librarian
# 943          student
# Name: occupation, Length: 943, dtype: object

# %%
print(data['occupation'])
# Out:
# user_id
# 1         technician
# 2              other
# 3             writer
# 4         technician
# 5              other
#            ...
# 939          student
# 940    administrator
# 941          student
# 942        librarian
# 943          student
# Name: occupation, Length: 943, dtype: object

# %% [markdown]
# ### 12. ¿Cuántas profesiones diferentes hay? ¿Y personas por profesión?

# %%
print(set(data['occupation'].values))
print(len(set(data['occupation'].values)))
# Out:
# {'programmer', 'artist', 'technician', 'other', 'salesman', 'lawyer', 'librarian', 'writer', 'student', 'educator', 'none', 'administrator', 'executive', 'doctor', 'scientist', 'homemaker', 'healthcare', 'marketing', 'engineer', 'entertainment', 'retired'}
# 21

# %%
data['occupation'].nunique()
# Out:
# 21

# %%
data['occupation'].unique()
# Out:
# array(['technician', 'other', 'writer', 'executive', 'administrator',
#        'student', 'lawyer', 'educator', 'scientist', 'entertainment',
#        'programmer', 'librarian', 'homemaker', 'artist', 'engineer',
#        'marketing', 'none', 'healthcare', 'retired', 'salesman', 'doctor'],
#       dtype=object)

# %%
data.groupby('occupation').count()
# Out:
#                age  gender  zip_code
# occupation
# administrator   79      79        79
# artist          28      28        28
# doctor           7       7         7
# educator        95      95        95
# engineer        67      67        67
# entertainment   18      18        18
# executive       32      32        32
# healthcare      16      16        16
# homemaker        7       7         7
# lawyer          12      12        12
# librarian       51      51        51
# marketing       26      26        26
# none             9       9         9
# other          105     105       105
# programmer      66      66        66
# retired         14      14        14
# salesman        12      12        12
# scientist       31      31        31
# student        196     196       196
# technician      27      27        27
# writer          45      45        45

# %% [markdown]
# ### 13. ¿Cuál es la profesión más común?

# %%
data.groupby('occupation').count().max()
# Out:
# age         196
# gender      196
# zip_code    196
# dtype: int64

# %% [markdown]
# ### 14. Obtén un resumen de las principales medidas estadísticas de las variables numéricas.  Usa describe()

# %%
data.describe()
# Out:
#               age
# count  943.000000
# mean    34.051962
# std     12.192740
# min      7.000000
# 25%     25.000000
# 50%     31.000000
# 75%     43.000000
# max     73.000000

# %% [markdown]
# ### 15. Obtén un resumen de las principales medidas estadísticas de todas las variables.  Usa describe()

# %%
data.describe(include='all')
# Out:
#                age gender occupation zip_code
# count   943.000000    943        943      943
# unique         NaN      2         21      795
# top            NaN      M    student    55414
# freq           NaN    670        196        9
# mean     34.051962    NaN        NaN      NaN
# std      12.192740    NaN        NaN      NaN
# min       7.000000    NaN        NaN      NaN
# 25%      25.000000    NaN        NaN      NaN
# 50%      31.000000    NaN        NaN      NaN
# 75%      43.000000    NaN        NaN      NaN
# max      73.000000    NaN        NaN      NaN

# %%
display(data.describe(), data.describe(include='object'))
# Out:
#               age
# count  943.000000
# mean    34.051962
# std     12.192740
# min      7.000000
# 25%     25.000000
# 50%     31.000000
# 75%     43.000000
# max     73.000000
#        gender occupation zip_code
# count     943        943      943
# unique      2         21      795
# top         M    student    55414
# freq      670        196        9

# %% [markdown]
# ### 16. Obtén un resumen de las principales medidas estadísticas de solo la columna occupation.  Usa describe()

# %%
data.describe('occupation')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 data.describe('occupation')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\generic.py:11976, in NDFrame.describe(self, percentiles, include, exclude)
#   11734 @final
#   11735 def describe(
#   11736     self,
#    (...)
#   11739     exclude=None,
#   11740 ) -> Self:
#   11741     """
#   11742     Generate descriptive statistics.
#   11743
#    (...)
#   11974     max            NaN      3.0
#   11975     """
# > 11976     return describe_ndframe(
#   11977         obj=self,
#   11978         include=include,
#   11979         exclude=exclude,
#   11980         percentiles=percentiles,
#   11981     ).__finalize__(self, method="describe")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\methods\describe.py:83, in describe_ndframe(obj, include, exclude, percentiles)
#      55 def describe_ndframe(
#      56     *,
#      57     obj: NDFrameT,
#    (...)
#      60     percentiles: Sequence[float] | np.ndarray | None,
#      61 ) -> NDFrameT:
#      62     """Describe series or dataframe.
#      63
#      64     Called from pandas.core.generic.NDFrame.describe()
#    (...)
#      81     Dataframe or series description.
#      82     """
# ---> 83     percentiles = _refine_percentiles(percentiles)
#      85     describer: NDFrameDescriberAbstract
#      86     if obj.ndim == 1:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\methods\describe.py:402, in _refine_percentiles(percentiles)
#     399 percentiles = list(percentiles)
#     401 # get them all to be in [0, 1]
# --> 402 validate_percentile(percentiles)
#     404 # median should always be included
#     405 if 0.5 not in percentiles:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\util\_validators.py:339, in validate_percentile(q)
#     337         raise ValueError(msg)
#     338 else:
# --> 339     if not all(0 <= qs <= 1 for qs in q_arr):
#     340         raise ValueError(msg)
#     341 return q_arr
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\util\_validators.py:339, in <genexpr>(.0)
#     337         raise ValueError(msg)
#     338 else:
# --> 339     if not all(0 <= qs <= 1 for qs in q_arr):
#     340         raise ValueError(msg)
#     341 return q_arr
#
# TypeError: '<=' not supported between instances of 'int' and 'numpy.str_'

# %% [markdown]
# ### 17. ¿Cuál es la edad media?

# %%
np.mean(data['age'])
# Out:
# 34.05196182396607

# %% [markdown]
# ### 18. ¿Cuál es la edad menos frecuente?
