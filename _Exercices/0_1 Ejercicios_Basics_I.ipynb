# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # Ejercicios Python Basics I

# %% [markdown]
# ## Ejercicio 0
# Imprime por pantalla esta cita con el siguiente formato
#
# ![imagen](./img/frase_Einstein.PNG)

# %%
print('¿Por qué esta magnífica tecnología científica,')
print('        que ahorra trabajo y nos hace la vida más fácil,')
print('                nos aporta tan poca felicidad?')
print('                        La respuesta está, simplemente: porque aún no hemos aprendido a usarla con tino.')
print('"Albert Einstein"')
# Out:
# ¿Por qué esta magnífica tecnología científica,
#         que ahorra trabajo y nos hace la vida más fácil,
#                 nos aporta tan poca felicidad?
#                         La respuesta está, simplemente: porque aún no hemos aprendido a usarla con tino.
# "Albert Einstein"

# %% [markdown]
# ## Ejercicio 1
# 1. Escribe el nombre de la calle de tu domicilio en una variable
# 2. Escribe el numero de la calle en otra
# 3. Ciudad en una tercera
# 4. Codigo postal en la cuarta variable
# 5. Imprime las 4 variables concatenadas por pantalla
# 6. Crea una quinta variable que concatene todas ellas
# 7. Imprímela por pantalla

# %%
calle = 'Gran Vía'
num = 33
ciudad = 'Bilbao'
codigo = 48001
print(calle, num, ciudad, codigo)
domicilio = calle + ' ' + str(num) + ' ' + ciudad + ' ' + str(codigo)
print(domicilio)
# Out:
# Gran Vía 33 Bilbao 48001
# Gran Vía 33 Bilbao 48001

# %% [markdown]
# ## Ejercicio 2
# Repite el ejercicio 1, pero pidiendo estos datos al usuario mediante un input(), imprimiendo a continuación la dirección completa

# %%
calle = input('Cual es tu calle? ')
num = input('Y el número de tu portal? ')
ciudad = input('En qué ciudad? ')
codigo = input('Por último dime tu código postal: ')
print(calle, num, ciudad, codigo)
domicilio = calle + ' ' + str(num) + ' ' + ciudad + ' ' + str(codigo)
print(domicilio)
# Out:
# Cual es tu calle? free
# Y el número de tu portal? 147
# En qué ciudad? dfsf
# Por último dime tu código postal: fdsgdfg
# free 147 dfsf fdsgdfg
# free 147 dfsf fdsgdfg

# %% [markdown]
# ## Ejercicio 3
# ¿Qué variables están mal escritas y por qué? Realiza primero tu hipótesis y luego ejecuta las variables para comprobarlo. En ese orden :)
#
#
# 1. mi_variable = "Economía"
# 2. otra_var = "Ejercicio
# 3. True = "Ejercicio"
# 4. mi variab1e = "Alpha"
# 5. import = 40
# 6. 81mi_variable = "Agua"
# 7. mi_variable10 = 6

# %% [markdown]
# Tus respuestas:
#
# 1. ✅ OK
# 2. ❌ Faltan las comilas de cierre
# 3. ❌ Palabra reservada
# 4. ❌ El nombre ha de ser un único string
# 5. ❌ Palabra reservada
# 6. ❌ No puede comenzar por número
# 7. ✅ OK

# %%
mi_variable = "Economía"

# %%
otra_var = "Ejercicio
# Out:
#   File "<ipython-input-2-0e2c550f24b6>", line 1
#     otra_var = "Ejercicio
#                ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
True = "Ejercicio"
# Out:
#   File "<ipython-input-6-584f15b0cc20>", line 1
#     True = "Ejercicio"
#     ^
# SyntaxError: cannot assign to True

# %%
mi variab1e = "Alpha"
# Out:
#   File "<ipython-input-3-6f6db994b804>", line 1
#     mi variab1e = "Alpha"
#        ^
# SyntaxError: invalid syntax

# %%
import = 40
# Out:
#   File "<ipython-input-7-8b78a9e867ce>", line 1
#     import = 40
#            ^
# SyntaxError: invalid syntax

# %%
81mi_variable = "Agua"
# Out:
#   File "<ipython-input-5-49ad8abd9385>", line 1
#     81mi_variable = "Agua"
#      ^
# SyntaxError: invalid decimal literal

# %%
mi_variable10 = 6

# %% [markdown]
# ## Ejercicio 4
# Realiza un conversor de grados Celsius a Fahrenheit. El conversor tiene que recibir el input del usuario y devolver la conversión.
#
# La conversión de grados sigue la siguiente fórmula: F = C × (9 / 5) + 32

# %%
grados_C = input('Dime el valor de la temperatura en grados Celsius: ')
grados_F = (int(grados_C) * (9 / 5) ) + 32
print(f'{grados_C} grados Celsius equivalen a {grados_F} grados Fahrenheit')
# Out:
# Dime el valor de la temperatura en grados Celsius: 50
# 50 grados Celsius equivalen a 122.0 grados Fahrenheit

# %% [markdown]
# ## Ejercicio 5
# Comenta  el Ejercicio 4. Pon un comentario multilinea y haz comentarios de cada linea de código

# %%
"""
Este script convierte una temperatura dada en grados Celsius a grados Fahrenheit.
El usuario debe introducir la temperatura en grados Celsius cuando se solicite.
El script imprime la temperatura equivalente en grados Fahrenheit.
"""

grados_C = input('Dime el valor de la temperatura en grados Celsius: ') # Solicita al usuario que introduzca la temperatura en grados Celsius y guarda el valor en la variable grados_C.

grados_F = (int(grados_C) * (9 / 5) ) + 32 # Convierte el valor de grados_C a entero, luego realiza la conversión de Celsius a Fahrenheit y guarda el resultado en la variable grados_F.

print(f'{grados_C} grados Celsius equivalen a {grados_F} grados Fahrenheit') # Imprime el resultado de la conversión en formato de cadena, mostrando tanto los grados Celsius originales como los grados Fahrenheit calculados.
